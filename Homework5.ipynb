# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
city_data = "city_data.csv"
ride_data = "ride_data.csv"
city_data_df = pd.read_csv('city_data.csv')
ride_data_df = pd.read_csv('ride_data.csv')

# %%
city_data_df = pd.read_csv('city_data.csv')
city_data_df.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
combined_data_df = pd.merge(city_data_df, ride_data_df,
                                 how='outer', on='city')
combined_data_df.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
combined_data_df = combined_data_df.groupby('ride_id')
combined_data_df.head()
# Out:
#                  city  driver_count   type                 date   fare  \
# 0         Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1         Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2         Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3         Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4         Richardfort            38  Urban  2018-04-17 02:26:37  23.00
# 5         Richardfort            38  Urban  2018-04-21 03:44:04   9.54
# 6         Richardfort            38  Urban  2018-02-03 00:14:26  29.04
# 7         Richardfort            38  Urban  2018-02-08 15:50:12  16.55
# 8         Richardfort            38  Urban  2018-04-03 15:07:34  40.77
# 9         Richardfort            38  Urban  2018-02-19 14:09:20  27.11
# 10        Richardfort            38  Urban  2018-04-22 03:06:56  39.74
# 11        Richardfort            38  Urban  2018-01-31 14:51:01  43.92
# ...

# %%
x_axis = np.arange(len(combined_data_df))
tic_locations = [value+1 for value in x_axis]

# %%
plt.figure(figsize=(20,3))
plt.bar(combined_data_df["fare"], combined_data_df["ride_id"], color='r', alpha=0.5, align="edge", rotation="vertical")
#plt.xticks(tic_locations,combined_data_df["city"], rotation ="vertical")
# Out:
# <div id='edf0aaa0-38c1-4d0c-a71e-9776a1586897'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-895f98775b92> in <module>()
#       1 plt.figure(figsize=(20,3))
# ----> 2 plt.bar(combined_data_df["fare"], combined_data_df["ride_id"], color='r', alpha=0.5, align="edge", rotation="vertical")
#       3 #plt.xticks(tic_locations,combined_data_df["city"], rotation ="vertical")
#       4
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(*args, **kwargs)
#    2646                       mplDeprecation)
#    2647     try:
# -> 2648         ret = ax.bar(*args, **kwargs)
#    2649     finally:
#    2650         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
combined_data_df = combined_data_df['city'].count()
combined_data_df
# Out:
# ride_id
# 321833677        1
# 1506044208       1
# 14588103145      1
# 16507766547      1
# 18586563147      1
# 23948941587      1
# 25082058503      1
# 26848733115      1
# 28294640252      1
# 30234681362      1
# 38504866921      1
# 39663640391      1
# 41356844955      1
# 56113993388      1
# 56240519093      1
# 57422927996      1
# 60590634054      1
# 73344113439      1
# 79314274773      1
# 83498621902      1
# 85473064902      1
# 90058815985      1
# 91435348621      1
# 93262977180      1
# 96327208793      1
# 99483095214      1
# 100023890906     1
# 100530645822     1
# 102684585771     1
# 103217578833     1
#                 ..
# 9810772317135    1
# 9813556258471    1
# 9825842278797    1
# 9830268750819    1
# 9834070706163    1
# 9835001920405    1
# 9839553829612    1
# 9839854233835    1
# 9840779665113    1
# 9847755706013    1
# 9867639864905    1
# 9877186615998    1
# 9877402838460    1
# 9878231118211    1
# 9903881959478    1
# 9905958460368    1
# ...

# %%
# Create a series that looks for a ride_id and then traces their cities
driver_cities = combined_data_df.loc [ride_id,["city"]
driver_fares = combined_data_df.loc[ride_id,["fare"]
# Out:
#   File "<ipython-input-20-bf6ec4a1ad03>", line 3
#     driver_fares = combined_data_df.loc[ride_id,["fare"]
#                ^
# SyntaxError: invalid syntax

# %%
plt.plot(driver_cities, color="green", label="Wins")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-a0ae1ce5d9fc> in <module>()
# ----> 1 plt.plot(driver_cities, color="green", label="Wins")
#
# NameError: name 'driver_cities' is not defined

# %%
#x_axis = np.arange(len(ride_data_df))
#tick_locations = (value for value in x_axis)

# %%
#plt.figure(figsize=(20,3))
#plt.bar(x_axis, ride_data_df["fare"],color ='r', alpha = 0.5, align = 'center')
#plt.xticks(tick_locations, ride_data_df["city"], rotation = 'vertical')
#city_and_driver_count = city_data_df[["city", "driver_count"]]
#city_and_driver_count = city_and_driver_count.set_index("city")
#city_and_driver_count.head()
city_count_df = city_data_df["city"].value_counts()
driver_data_df = city_data_df["driver_count"].value_counts()
fare_data_df = ride_data_df["fare"].average()
city_type_df = city_data_df["type"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-769b3c3f9187> in <module>()
#       7 city_count_df = city_data_df["city"].value_counts()
#       8 driver_data_df = city_data_df["driver_count"].value_counts()
# ----> 9 fare_data_df = ride_data_df["fare"].average()
#      10 city_type_df = city_data_df["type"].value_counts()
#      11
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'average'

# %%
#ride_data['fare'] = pd.to_numeric(ride_data['fare'])
city_data_data_df = city_count_df.add(driver_data_df, city_type_df, fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-90fb56676c7d> in <module>()
#       1
#       2 #ride_data['fare'] = pd.to_numeric(ride_data['fare'])
# ----> 3 city_data_data_df = city_count_df.add(driver_data_df, city_type_df, fill_value=0)
#
# NameError: name 'city_type_df' is not defined

# %%
city_data_data_df.plot(kind="bubble", facecolor="red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-ec7146e5c7fc> in <module>()
# ----> 1 city_data_data_df.plot(kind="bubble", facecolor="red")
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ...

# %%
plt.title("The Cities and Driver Data")
plt.ylabel("Number of Drivers")
plt.xlabel("Cities")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0,'Cities')

# %%
#ride_data.plot(kind="scatter", x="fare", y="city", grid=True, figsize=(20,10),
              #title="fare Vs. city")
plt.show()

# %%
plt.tight_layout()
